# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
model.train(
    data="classes.yaml",
    batch=4,
    epochs=200,
    patience=20,
    device=0,
    project="YOLOv8",
    name="YOLOv8",
    verbose=True
)
# Out:
# Ultralytics YOLOv8.0.91  Python-3.9.16 torch-2.0.1 CUDA:0 (Quadro P2000, 5120MiB)
# ...
