# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
model.train(
    data="classes.yaml",
    epochs=300,
    patience=20,
    device=0,
    project="YOLOv8m",
    name="YOLOv8m_noclassweight",
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.115 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-PCIE-40GB, 40354MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
model.val(split="test")
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-PCIE-40GB, 40354MiB)
# val: Scanning /home/computervision_zl/Documents/computervision/yolo_datasets/labels/test... 186 images, 0 backgrounds, 0 corrupt: 100%|██████████| 186/186 [00:00<00:00, 1287.23it/s]
# val: New cache created: /home/computervision_zl/Documents/computervision/yolo_datasets/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [00:04<00:00,  2.40it/s]
#                    all        186        766      0.747      0.672       0.74      0.506
#            scribe_line        186        141      0.924       0.95      0.955      0.831
#                    pad        186        371      0.979      0.995      0.995      0.859
#                  flake        186          8      0.542      0.375      0.513      0.422
#                   burr        186         33      0.707      0.455      0.546       0.27
# ...
