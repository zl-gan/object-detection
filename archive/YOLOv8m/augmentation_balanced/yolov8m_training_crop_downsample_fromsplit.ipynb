# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
model.train(
    data="final_crop_downsample_fromsplit/yolo_datasets/classes.yaml",
    epochs=300,
    patience=20,
    device=0,
    project="YOLOv8",
    name="YOLOv8_crop_downsample_fromsplit",
    verbose=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.114 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-PCIE-40GB, 40354MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
model = YOLO("/home/computervision_zl/Documents/DP_AOI/YOLOv8/YOLOv8_crop_downsample_fromsplit/weights/best.pt")
model.val("final_crop_downsample_fromsplit/yolo_datasets/classes.yaml", split="test")
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-PCIE-40GB, 40354MiB)
# Model summary (fused): 218 layers, 25847287 parameters, 0 gradients
# val: Scanning /home/computervision_zl/Documents/DP_AOI/final_crop_downsample_fromsplit/yolo_datasets/labels/test... 512 images, 0 backgrounds, 0 corrupt: 100%|██████████| 512/512 [00:00<00:00, 1709.18it/s]
# val: New cache created: /home/computervision_zl/Documents/DP_AOI/final_crop_downsample_fromsplit/yolo_datasets/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 32/32 [00:04<00:00,  6.47it/s]
#                    all        512       1373      0.856      0.786      0.883      0.706
#               discolor        512         58      0.989          1      0.995      0.943
#                fly_die        512         56      0.878      0.982      0.992      0.937
# ...
