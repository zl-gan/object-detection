# %%
import os

os.chdir('drive/MyDrive/Colab Notebooks/')

# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 23.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('YOLOv8/YOLOv82/weights/last.pt')

# %%
model.train(
    data="datasets/yolo_datasets/classes.yaml",
    device=0,
    project="YOLOv8",
    name="YOLOv8", 
    verbose=True, 
    resume=True
)
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
