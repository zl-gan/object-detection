# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_1.py work_dirs/fasterrcnn_1/best_coco_bbox_mAP_epoch_132.pth
# Out:
# 06/20 13:24:44 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 665283035
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_2.py work_dirs/fasterrcnn_2/best_coco_bbox_mAP_epoch_145.pth
# Out:
# 06/20 13:28:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 382670916
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_3.py work_dirs/fasterrcnn_3/best_coco_bbox_mAP_epoch_1.pth
# Out:
# 06/20 13:31:27 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 660494434
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_4.py work_dirs/fasterrcnn_4/best_coco_bbox_mAP_epoch_51.pth
# Out:
# 06/20 13:35:35 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 182272850
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_5.py work_dirs/fasterrcnn_5/best_coco_bbox_mAP_epoch_144.pth
# Out:
# 06/20 13:38:56 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 190835793
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_6.py work_dirs/fasterrcnn_6/best_coco_bbox_mAP_epoch_145.pth

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_7.py work_dirs/fasterrcnn_7/best_coco_bbox_mAP_epoch_1.pth

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py fasterrcnn_8.py work_dirs/fasterrcnn_8/best_coco_bbox_mAP_epoch_45.pth
