# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_1.py work_dirs/retinanet_1/best_coco_bbox_mAP_epoch_140.pth
# Out:
# 06/21 22:57:59 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 766119434
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_2.py work_dirs/retinanet_2/best_coco_bbox_mAP_epoch_72.pth
# Out:
# 06/21 23:01:19 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 761296374
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_3.py work_dirs/retinanet_3/best_coco_bbox_mAP_epoch_1.pth
# Out:
# 06/21 23:04:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 717948635
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_4.py work_dirs/retinanet_4/best_coco_bbox_mAP_epoch_140.pth
# Out:
# 06/22 07:46:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 495932255
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_5.py work_dirs/retinanet_5/best_coco_bbox_mAP_epoch_142.pth
# Out:
# 06/21 23:07:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1735731864
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_6.py work_dirs/retinanet_6/best_coco_bbox_mAP_epoch_137.pth
# Out:
# 06/21 23:11:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 354557777
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_7.py work_dirs/retinanet_7/best_coco_bbox_mAP_epoch_1.pth
# Out:
# 06/22 07:49:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1293166471
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py retinanet_8.py work_dirs/retinanet_8/best_coco_bbox_mAP_epoch_91.pth
# Out:
# 06/21 23:14:45 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1317350712
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...
