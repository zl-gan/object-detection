# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_1.py work_dirs/ssd_1/best_coco_bbox_mAP_epoch_147.pth
# Out:
# 06/22 14:13:55 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1737136496
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_2.py work_dirs/ssd_2/best_coco_bbox_mAP_epoch_144.pth
# Out:
# 06/22 14:17:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1944994299
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_3.py work_dirs/ssd_3/best_coco_bbox_mAP_epoch_1.pth
# Out:
# 06/22 14:20:29 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 918761713
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_4.py work_dirs/ssd_4/best_coco_bbox_mAP_epoch_4.pth
# Out:
# 06/22 14:23:48 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1105160488
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_5.py work_dirs/ssd_5/best_coco_bbox_mAP_epoch_139.pth
# Out:
# 06/22 14:27:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1331397188
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_6.py work_dirs/ssd_6/best_coco_bbox_mAP_epoch_143.pth
# Out:
# 06/22 14:30:24 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 474803381
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_7.py work_dirs/ssd_7/best_coco_bbox_mAP_epoch_3.pth
# Out:
# 06/22 14:33:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 2109156856
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...

# %%
! python3 /home/computervision_zl/mmdetection/tools/test.py ssd_8.py work_dirs/ssd_8/best_coco_bbox_mAP_epoch_147.pth
# Out:
# 06/22 14:37:05 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 463201755
#     GPU 0: NVIDIA A100-PCIE-40GB
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
# ...
